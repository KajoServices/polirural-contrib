# %% [markdown]
# # Explore topic similarities with WMD similarity measure
#
# * comparing keywords found in texts with topics using word mover distance to find a reasonable threshold for wmd similarity keyword-topic
# * found WMD threshold = 1.0

# %%
import spacy
from tqdm import tqdm
from pprint import pprint
import time


import numpy as np
import math

import os

import pytextrank

# %%
from gensim.models import Word2Vec, KeyedVectors
slim_model_name = '/home/dzon/kajo/word2vec-slim/w2v-jiri-slim.bin'
start = time.time()
model = KeyedVectors.load_word2vec_format(slim_model_name, binary=True)
print('Finished loading model %.4f s' % ((time.time()-start)))
start = time.time()
#normalize vectors - needed for better performance of WMD
model.init_sims(replace=True)
print('Finished normalizing vectors %.4f s' % ((time.time()-start)))
# Out:
# Finished loading model 3.2377 s
# Finished normalizing vectors 0.0899 s

# %%
#get topics from file
with open('/home/dzon/kajo/semantic-explorer/data/topic_list_v3.txt') as fp:
    topics_file = fp.readlines()
topics = []
for topic in topics_file:
    topic = topic.strip().lower()
    if topic not in topics:
        topics.append(topic)

# %%
topic_sims = {}
for i in tqdm(range(len(topics))):
    for j in range(i+1,len(topics)):
        topic1 = topics[i]
        topic2 = topics[j]
        wmd = model.wmdistance(topic1.split("_"), topic2.split("_")) 
        t_key = "{}-{}".format(topic1, topic2)
        topic_sims[t_key] = wmd
# Out:
# 100%|██████████| 422/422 [00:12<00:00, 33.39it/s]

# %%
sorted_topic_sims = sorted(topic_sims.items(),
                          key=lambda kv: kv[1],
                          reverse=False)
print('Most similar topics:')
pprint(sorted_topic_sims[:10])
print("\nLeast similar topics:")
pprint(sorted_topic_sims[-10:])

print("\nTopics with sim > 1:")
#pprint([(t,s) for (t,s) in sorted_topic_sims if s>1])
print(len([(t,s) for (t,s) in sorted_topic_sims if s>1]))
print("\nTopics with sim <= 1:")
print(len([(t,s) for (t,s) in sorted_topic_sims if s<=1]))
# Out:
# Most similar topics:
# [('illegal_immigrants-illegal_migrants', 0.25969861426860097),
#  ('irregular_migrants-irregular_immigrants', 0.25969867834281923),
#  ('flemish_region-walloon_region', 0.26490518466144797),
#  ('smaller_companies-larger_companies', 0.27452466300517325),
#  ('smaller_firms-larger_firms', 0.27452476633280515),
#  ('smaller_enterprises-larger_enterprises', 0.27452497996866704),
#  ('lower_wages-higher_wages', 0.28893259796476367),
#  ('upper_secondary_education-lower_secondary_education', 0.2902137666652251),
#  ('permanent_pasture-permanent_pastures', 0.297483636610508),
#  ('young_women-young_men', 0.30129122592914104)]
#
# Least similar topics:
# [('certification_programme-flash_floods', 1.3530118881440163),
#  ('irregular_immigrants-leader_programme', 1.353569445798397),
#  ('funding_cuts-riparian_vegetation', 1.3536500371118187),
#  ('eu_regulations-soil_degradation', 1.3540491406162978),
#  ('eu_rules-riparian_vegetation', 1.3543952122431993),
#  ('eu_rules-soil_degradation', 1.354561985544145),
#  ('low_productivity-unaccompanied_minors', 1.355170265071869),
#  ('proven_expertise-unaccompanied_minors', 1.3554522609090804),
#  ('landscape_maintenance-asylum_seekers', 1.3565358102423548),
#  ('eu_rules-soil_erosion', 1.3602110927913187)]
#
# Topics with sim > 1:
# 86672
#
# Topics with sim <= 1:
# 2159

# %%
words_number = {}
for topic in topics:
    words = len(topic.split("_"))
    try:
        words_number[words] += 1
    except:
        words_number[words] = 1
pprint(words_number)
# Out:
# {2: 378, 3: 38, 4: 6}

# %%
 def get_keywords(text=None, keywords=10, **kwargs):
        """ Get keywords from text using TextRank algorithm implemented in pytextrank """
        # Option to get raw keywords without any processing
        raw_keywords = kwargs.get("raw_keywords", False)
        if "textrank" not in nlp.pipe_names:
            tr = pytextrank.TextRank()
            nlp.add_pipe(tr.PipelineComponent, name="textrank", last=True)
        keywords_dict = {}
        doc = nlp(text)
        i = 0
        for p in doc._.phrases:
            p_doc = nlp(p.text)
            keyword_text = []
            for token in p_doc:
                # for purposes of the topic extraction, we clean the keyword phrases
                if token.is_punct or token.is_space or token.is_stop or (len(token) < 2):
                    continue
                keyword_text.append(token.lemma_)
            if keyword_text == []:
                continue
            keyword = "_".join(keyword_text)
            if raw_keywords:
                keyword = p.text
            # the keyword after lemmatization and token filtering can be already in the list
            if keyword in keywords_dict:
                if keywords_dict[keyword] < p.rank:
                    keywords_dict[keyword] = p.rank
            else:
                keywords_dict[keyword] = p.rank
                i += 1
            if i == keywords:
                break
        return keywords_dict

# %%
nlp = spacy.load("en_core_web_sm")
keywords = []
keywords_raw = []

for dirpath, dirnames, filenames in os.walk("/home/dzon/kajo/vito-texts-utf8"):
    i = 0
    for filename in [f for f in filenames if f.endswith(".txt")]:
        print (os.path.join(dirpath, filename))
        text_file = os.path.join(dirpath, filename)
        with open(text_file, encoding="utf-8", mode="r") as fp:
            text = fp.read() 
        kw_dic = get_keywords(text,keywords=1000)   
        print(len(kw_dic))
        for key in kw_dic.keys():
            keywords.append(key)
        #pprint(kw_dic)
        kw_raw_dic = get_keywords(text,keywords=1000,raw_keywords=True)   
        print(len(kw_raw_dic))
        for key in kw_raw_dic.keys():
            keywords_raw.append(key)
# Out:
# /home/dzon/kajo/vito-texts-utf8/agricultural_productivity_full.txt
# 40
# 40
# /home/dzon/kajo/vito-texts-utf8/report-summaries_self-reliance-agriculture-food-discussion.txt
# 65
# 68
# /home/dzon/kajo/vito-texts-utf8/organic_agriculture.txt
# 102
# 104
# /home/dzon/kajo/vito-texts-utf8/report-summaries_loss-and-waste-food-chain.txt
# 187
# 188
# /home/dzon/kajo/vito-texts-utf8/report-summaries_risk-management-agriculture-and-horticulture.txt
# 542
# 561
# /home/dzon/kajo/vito-texts-utf8/report-summaries_impact-direct-support-business-income.txt
# 108
# 112
# /home/dzon/kajo/vito-texts-utf8/report-summaries_innovation-agriculture-and-horticulture.txt
# 178
# 183
# /home/dzon/kajo/vito-texts-utf8/role_of_water_in_agricultural_development.txt
# 888
# 912
# /home/dzon/kajo/vito-texts-utf8/report-summaries_production-account-flemish-agriculture-and.txt
# 70
# 70
# /home/dzon/kajo/vito-texts-utf8/report-summaries_organic-agriculture-2009.txt
# 119
# 119
# /home/dzon/kajo/vito-texts-utf8/report-summaries_scientific-report-mira-2009-sub-sector.txt
# 151
# 155
# /home/dzon/kajo/vito-texts-utf8/rural_cycling.txt
# 146
# 151
# /home/dzon/kajo/vito-texts-utf8/agricultural_productivity_short.txt
# 5
# 5
# /home/dzon/kajo/vito-texts-utf8/flanders_wiki.txt
# 405
# 407
# /home/dzon/kajo/vito-texts-utf8/agricultural_productivity_1paragraph.txt
# 8
# 9
# /home/dzon/kajo/vito-texts-utf8/report-summaries_selection-plan-flemish-farm-accountancy-data.txt
# 61
# 62
# /home/dzon/kajo/vito-texts-utf8/report-summaries_indicators-monitoring-agricultural-land-high.txt
# 253
# 261
# /home/dzon/kajo/vito-texts-utf8/report-summaries_profitability-report-agriculture-and.txt
# 79
# 79
# /home/dzon/kajo/vito-texts-utf8/mechanized_agriculture.txt
# 189
# 193

# %%
topic_kw_sims = {}  
for i in tqdm(range(len(topics))):
    for j in range(len(keywords)):
        topic1 = topics[i]
        topic2 = keywords[j]
        wmd = model.wmdistance(topic1.split("_"), topic2.split("_")) 
        t_key = "{}-{}".format(topic1, topic2)
        topic_kw_sims[t_key] = wmd
# Out:
#   0%|          | 0/422 [00:00<?, ?it/s]
#
#
#   0%|          | 1/422 [00:00<03:11,  2.20it/s]
#
#
#   0%|          | 2/422 [00:00<03:09,  2.22it/s]
#
#
#   1%|          | 3/422 [00:01<03:09,  2.21it/s]
#
#
#   1%|          | 4/422 [00:01<03:09,  2.21it/s]
#
#
#   1%|          | 5/422 [00:02<03:09,  2.20it/s]
#
#
#   1%|▏         | 6/422 [00:02<03:07,  2.22it/s]
#
#
#   2%|▏         | 7/422 [00:03<03:06,  2.22it/s]
#
#
#   2%|▏         | 8/422 [00:03<03:05,  2.23it/s]
#
#
#   2%|▏         | 9/422 [00:04<03:04,  2.24it/s]
#
#
#   2%|▏         | 10/422 [00:04<03:03,  2.25it/s]
#
#
#   3%|▎         | 11/422 [00:04<03:01,  2.26it/s]
#
#
#   3%|▎         | 12/422 [00:05<03:14,  2.11it/s]
#
#
#   3%|▎         | 13/422 [00:05<03:08,  2.16it/s]
#
#
#   3%|▎         | 14/422 [00:06<03:07,  2.18it/s]
#
#
#   4%|▎         | 15/422 [00:06<03:05,  2.20it/s]
#
#
#   4%|▍         | 16/422 [00:07<03:19,  2.03it/s]
#
#
#   4%|▍         | 17/422 [00:07<03:15,  2.07it/s]
#
#
#   4%|▍         | 18/422 [00:08<03:12,  2.10it/s]
#
#
#   5%|▍         | 19/422 [00:08<03:08,  2.14it/s]
#
#
#   5%|▍         | 20/422 [00:09<03:05,  2.17it/s]
#
#
#   5%|▍         | 21/422 [00:09<03:01,  2.21it/s]
#
#
#   5%|▌         | 22/422 [00:10<03:01,  2.21it/s]
#
#
#   5%|▌         | 23/422 [00:10<03:01,  2.20it/s]
#
#
#   6%|▌         | 24/422 [00:10<03:00,  2.20it/s]
#
#
#   6%|▌         | 25/422 [00:11<02:59,  2.21it/s]
#
#
#   6%|▌         | 26/422 [00:11<03:12,  2.06it/s]
#
#
#   6%|▋         | 27/422 [00:12<03:06,  2.12it/s]
#
#
#   7%|▋         | 28/422 [00:12<03:03,  2.14it/s]
#
#
#   7%|▋         | 29/422 [00:13<03:15,  2.02it/s]
#
#
#   7%|▋         | 30/422 [00:13<03:08,  2.07it/s]
#
#
#   7%|▋         | 31/422 [00:14<03:04,  2.12it/s]
#
#
#   8%|▊         | 32/422 [00:14<03:01,  2.15it/s]
#
#
#   8%|▊         | 33/422 [00:15<02:58,  2.18it/s]
#
#
#   8%|▊         | 34/422 [00:15<02:55,  2.21it/s]
#
#
#   8%|▊         | 35/422 [00:16<02:55,  2.21it/s]
#
#
#   9%|▊         | 36/422 [00:16<02:53,  2.22it/s]
#
#
#   9%|▉         | 37/422 [00:17<02:53,  2.22it/s]
#
#
#   9%|▉         | 38/422 [00:17<02:51,  2.24it/s]
#
#
#   9%|▉         | 39/422 [00:17<02:51,  2.23it/s]
#
#
#   9%|▉         | 40/422 [00:18<02:50,  2.24it/s]
#
#
#  10%|▉         | 41/422 [00:18<02:50,  2.23it/s]
#
#
#  10%|▉         | 42/422 [00:19<02:50,  2.23it/s]
#
#
#  10%|█         | 43/422 [00:19<02:49,  2.24it/s]
#
#
#  10%|█         | 44/422 [00:20<02:48,  2.24it/s]
#
#
#  11%|█         | 45/422 [00:20<02:48,  2.24it/s]
#
#
#  11%|█         | 46/422 [00:21<02:47,  2.24it/s]
#
#
#  11%|█         | 47/422 [00:21<02:47,  2.24it/s]
#
#
#  11%|█▏        | 48/422 [00:22<02:59,  2.08it/s]
#
#
#  12%|█▏        | 49/422 [00:22<02:55,  2.12it/s]
#
#
#  12%|█▏        | 50/422 [00:23<03:05,  2.01it/s]
#
#
#  12%|█▏        | 51/422 [00:23<02:58,  2.08it/s]
#
#
#  12%|█▏        | 52/422 [00:23<02:53,  2.13it/s]
#
#
#  13%|█▎        | 53/422 [00:24<02:49,  2.17it/s]
#
#
#  13%|█▎        | 54/422 [00:24<02:48,  2.18it/s]
#
#
#  13%|█▎        | 55/422 [00:25<02:47,  2.19it/s]
#
#
#  13%|█▎        | 56/422 [00:25<02:45,  2.21it/s]
#
#
#  14%|█▎        | 57/422 [00:26<02:43,  2.23it/s]
#
#
#  14%|█▎        | 58/422 [00:26<02:42,  2.24it/s]
#
#
#  14%|█▍        | 59/422 [00:27<02:42,  2.23it/s]
#
#
#  14%|█▍        | 60/422 [00:27<02:53,  2.08it/s]
#
#
#  14%|█▍        | 61/422 [00:28<02:51,  2.11it/s]
#
#
#  15%|█▍        | 62/422 [00:28<02:49,  2.12it/s]
#
#
#  15%|█▍        | 63/422 [00:29<02:47,  2.14it/s]
#
#
#  15%|█▌        | 64/422 [00:29<02:45,  2.16it/s]
#
#
#  15%|█▌        | 65/422 [00:29<02:45,  2.16it/s]
#
#
#  16%|█▌        | 66/422 [00:30<02:44,  2.17it/s]
#
#
#  16%|█▌        | 67/422 [00:30<02:42,  2.18it/s]
#
#
#  16%|█▌        | 68/422 [00:31<02:42,  2.18it/s]
#
#
#  16%|█▋        | 69/422 [00:31<02:42,  2.17it/s]
#
#
#  17%|█▋        | 70/422 [00:32<02:41,  2.17it/s]
#
#
#  17%|█▋        | 71/422 [00:32<02:52,  2.03it/s]
#
#
#  17%|█▋        | 72/422 [00:33<02:48,  2.08it/s]
#
#
#  17%|█▋        | 73/422 [00:33<02:58,  1.96it/s]
#
#
#  18%|█▊        | 74/422 [00:34<02:51,  2.03it/s]
#
#
#  18%|█▊        | 75/422 [00:34<02:48,  2.06it/s]
#
#
#  18%|█▊        | 76/422 [00:35<02:44,  2.10it/s]
#
#
#  18%|█▊        | 77/422 [00:35<02:42,  2.13it/s]
#
#
#  18%|█▊        | 78/422 [00:36<02:52,  1.99it/s]
#
#
#  19%|█▊        | 79/422 [00:36<02:48,  2.03it/s]
#
#
#  19%|█▉        | 80/422 [00:37<02:45,  2.06it/s]
#
#
#  19%|█▉        | 81/422 [00:37<02:42,  2.10it/s]
#
#
#  19%|█▉        | 82/422 [00:38<02:39,  2.13it/s]
#
#
#  20%|█▉        | 83/422 [00:38<02:37,  2.15it/s]
#
#
#  20%|█▉        | 84/422 [00:38<02:36,  2.16it/s]
#
#
#  20%|██        | 85/422 [00:39<02:35,  2.16it/s]
#
#
#  20%|██        | 86/422 [00:39<02:34,  2.18it/s]
#
#
#  21%|██        | 87/422 [00:40<02:32,  2.20it/s]
#
#
#  21%|██        | 88/422 [00:40<02:31,  2.21it/s]
#
#
#  21%|██        | 89/422 [00:41<02:30,  2.21it/s]
#
#
#  21%|██▏       | 90/422 [00:41<02:29,  2.22it/s]
#
#
#  22%|██▏       | 91/422 [00:42<02:29,  2.21it/s]
#
#
#  22%|██▏       | 92/422 [00:42<02:28,  2.22it/s]
#
#
#  22%|██▏       | 93/422 [00:43<02:27,  2.23it/s]
#
#
#  22%|██▏       | 94/422 [00:43<02:27,  2.22it/s]
#
#
#  23%|██▎       | 95/422 [00:43<02:26,  2.23it/s]
#
#
#  23%|██▎       | 96/422 [00:44<02:25,  2.24it/s]
#
#
#  23%|██▎       | 97/422 [00:44<02:24,  2.24it/s]
#
#
#  23%|██▎       | 98/422 [00:45<02:23,  2.25it/s]
#
#
#  23%|██▎       | 99/422 [00:45<02:23,  2.24it/s]
#
#
#  24%|██▎       | 100/422 [00:46<02:24,  2.22it/s]
#
#
#  24%|██▍       | 101/422 [00:46<02:24,  2.22it/s]
#
#
#  24%|██▍       | 102/422 [00:47<02:36,  2.04it/s]
#
#
#  24%|██▍       | 103/422 [00:47<02:32,  2.09it/s]
#
#
#  25%|██▍       | 104/422 [00:48<02:29,  2.13it/s]
#
#
#  25%|██▍       | 105/422 [00:48<02:27,  2.14it/s]
#
#
#  25%|██▌       | 106/422 [00:49<02:26,  2.16it/s]
#
#
#  25%|██▌       | 107/422 [00:49<02:24,  2.17it/s]
#
#
#  26%|██▌       | 108/422 [00:49<02:24,  2.18it/s]
#
#
#  26%|██▌       | 109/422 [00:50<02:23,  2.18it/s]
#
#
#  26%|██▌       | 110/422 [00:50<02:22,  2.19it/s]
#
#
#  26%|██▋       | 111/422 [00:51<02:32,  2.04it/s]
#
#
#  27%|██▋       | 112/422 [00:51<02:28,  2.08it/s]
#
#
#  27%|██▋       | 113/422 [00:52<02:26,  2.11it/s]
#
#
#  27%|██▋       | 114/422 [00:52<02:23,  2.14it/s]
#
#
#  27%|██▋       | 115/422 [00:53<02:22,  2.15it/s]
#
#
#  27%|██▋       | 116/422 [00:53<02:21,  2.16it/s]
#
#
#  28%|██▊       | 117/422 [00:54<02:19,  2.18it/s]
#
#
#  28%|██▊       | 118/422 [00:54<02:19,  2.18it/s]
#
#
#  28%|██▊       | 119/422 [00:55<02:19,  2.18it/s]
#
#
#  28%|██▊       | 120/422 [00:55<02:18,  2.18it/s]
#
#
#  29%|██▊       | 121/422 [00:55<02:17,  2.20it/s]
#
#
#  29%|██▉       | 122/422 [00:56<02:16,  2.20it/s]
#
#
#  29%|██▉       | 123/422 [00:56<02:16,  2.19it/s]
#
#
#  29%|██▉       | 124/422 [00:57<02:17,  2.17it/s]
#
#
#  30%|██▉       | 125/422 [00:57<02:16,  2.18it/s]
#
#
#  30%|██▉       | 126/422 [00:58<02:15,  2.18it/s]
#
#
#  30%|███       | 127/422 [00:58<02:14,  2.20it/s]
#
#
#  30%|███       | 128/422 [00:59<02:13,  2.21it/s]
#
#
#  31%|███       | 129/422 [00:59<02:12,  2.21it/s]
#
#
#  31%|███       | 130/422 [01:00<02:21,  2.06it/s]
#
#
#  31%|███       | 131/422 [01:00<02:17,  2.11it/s]
#
#
#  31%|███▏      | 132/422 [01:01<02:15,  2.14it/s]
#
#
#  32%|███▏      | 133/422 [01:01<02:13,  2.17it/s]
#
#
#  32%|███▏      | 134/422 [01:01<02:11,  2.19it/s]
#
#
#  32%|███▏      | 135/422 [01:02<02:11,  2.18it/s]
#
#
#  32%|███▏      | 136/422 [01:02<02:10,  2.19it/s]
#
#
#  32%|███▏      | 137/422 [01:03<02:09,  2.20it/s]
#
#
#  33%|███▎      | 138/422 [01:03<02:08,  2.21it/s]
#
#
#  33%|███▎      | 139/422 [01:04<02:17,  2.05it/s]
#
#
#  33%|███▎      | 140/422 [01:04<02:23,  1.97it/s]
#
#
#  33%|███▎      | 141/422 [01:05<02:17,  2.05it/s]
#
#
#  34%|███▎      | 142/422 [01:05<02:13,  2.10it/s]
#
#
#  34%|███▍      | 143/422 [01:06<02:09,  2.15it/s]
#
#
#  34%|███▍      | 144/422 [01:06<02:07,  2.19it/s]
#
#
#  34%|███▍      | 145/422 [01:07<02:05,  2.21it/s]
#
#
#  35%|███▍      | 146/422 [01:07<02:03,  2.24it/s]
#
#
#  35%|███▍      | 147/422 [01:08<02:12,  2.08it/s]
#
#
#  35%|███▌      | 148/422 [01:08<02:09,  2.12it/s]
#
#
#  35%|███▌      | 149/422 [01:08<02:07,  2.14it/s]
#
#
#  36%|███▌      | 150/422 [01:09<02:04,  2.18it/s]
#
#
#  36%|███▌      | 151/422 [01:09<02:03,  2.20it/s]
#
#
#  36%|███▌      | 152/422 [01:10<02:01,  2.21it/s]
#
#
#  36%|███▋      | 153/422 [01:10<02:10,  2.06it/s]
#
#
#  85%|████████▌ | 359/422 [02:45<00:27,  2.28it/s]
#
#
#  85%|████████▌ | 360/422 [02:46<00:29,  2.11it/s]
#
#
#  86%|████████▌ | 361/422 [02:46<00:28,  2.16it/s]
#
#
#  86%|████████▌ | 362/422 [02:47<00:27,  2.19it/s]
#
#
#  86%|████████▌ | 363/422 [02:47<00:26,  2.21it/s]
#
#
#  86%|████████▋ | 364/422 [02:48<00:26,  2.23it/s]
#
#
#  86%|████████▋ | 365/422 [02:48<00:25,  2.24it/s]
#
#
#  87%|████████▋ | 366/422 [02:49<00:24,  2.25it/s]
#
#
#  87%|████████▋ | 367/422 [02:49<00:24,  2.21it/s]
#
#
#  87%|████████▋ | 368/422 [02:50<00:24,  2.19it/s]
#
#
#  87%|████████▋ | 369/422 [02:50<00:24,  2.18it/s]
#
#
#  88%|████████▊ | 370/422 [02:50<00:23,  2.17it/s]
#
#
#  88%|████████▊ | 371/422 [02:51<00:26,  1.92it/s]
#
#
#  88%|████████▊ | 372/422 [02:52<00:25,  1.99it/s]
#
#
#  88%|████████▊ | 373/422 [02:52<00:23,  2.05it/s]
#
#
#  89%|████████▊ | 374/422 [02:52<00:22,  2.09it/s]
#
#
#  89%|████████▉ | 375/422 [02:53<00:22,  2.13it/s]
#
#
#  89%|████████▉ | 376/422 [02:53<00:21,  2.16it/s]
#
#
#  89%|████████▉ | 377/422 [02:54<00:20,  2.15it/s]
#
#
#  90%|████████▉ | 378/422 [02:54<00:20,  2.17it/s]
#
#
#  90%|████████▉ | 379/422 [02:55<00:19,  2.18it/s]
#
#
#  90%|█████████ | 380/422 [02:55<00:19,  2.19it/s]
#
#
#  90%|█████████ | 381/422 [02:56<00:18,  2.20it/s]
#
#
#  91%|█████████ | 382/422 [02:56<00:18,  2.18it/s]
#
#
#  91%|█████████ | 383/422 [02:57<00:17,  2.18it/s]
#
#
#  91%|█████████ | 384/422 [02:57<00:17,  2.18it/s]
#
#
#  91%|█████████ | 385/422 [02:57<00:16,  2.19it/s]
#
#
#  91%|█████████▏| 386/422 [02:58<00:16,  2.20it/s]
#
#
#  92%|█████████▏| 387/422 [02:58<00:15,  2.20it/s]
#
#
#  92%|█████████▏| 388/422 [02:59<00:15,  2.22it/s]
#
#
#  92%|█████████▏| 389/422 [02:59<00:14,  2.23it/s]
#
#
#  92%|█████████▏| 390/422 [03:00<00:14,  2.21it/s]
#
#
#  93%|█████████▎| 391/422 [03:00<00:13,  2.23it/s]
#
#
#  93%|█████████▎| 392/422 [03:01<00:13,  2.21it/s]
#
#
#  93%|█████████▎| 393/422 [03:01<00:13,  2.21it/s]
#
#
#  93%|█████████▎| 394/422 [03:02<00:12,  2.21it/s]
#
#
#  94%|█████████▎| 395/422 [03:02<00:12,  2.21it/s]
#
#
#  94%|█████████▍| 396/422 [03:02<00:11,  2.20it/s]
#
#
#  94%|█████████▍| 397/422 [03:03<00:11,  2.20it/s]
#
#
#  94%|█████████▍| 398/422 [03:03<00:10,  2.20it/s]
#
#
#  95%|█████████▍| 399/422 [03:04<00:11,  2.06it/s]
#
#
#  95%|█████████▍| 400/422 [03:04<00:10,  2.12it/s]
#
#
#  95%|█████████▌| 401/422 [03:05<00:09,  2.14it/s]
#
#
#  95%|█████████▌| 402/422 [03:05<00:09,  2.16it/s]
#
#
#  95%|█████████▌| 403/422 [03:06<00:08,  2.18it/s]
#
#
#  96%|█████████▌| 404/422 [03:06<00:08,  2.03it/s]
#
#
#  96%|█████████▌| 405/422 [03:07<00:08,  2.08it/s]
#
#
#  96%|█████████▌| 406/422 [03:07<00:07,  2.13it/s]
#
#
#  96%|█████████▋| 407/422 [03:08<00:07,  2.01it/s]
#
#
#  97%|█████████▋| 408/422 [03:08<00:07,  1.93it/s]
#
#
#  97%|█████████▋| 409/422 [03:09<00:06,  2.02it/s]
#
#
#  97%|█████████▋| 410/422 [03:09<00:05,  2.09it/s]
#
#
#  97%|█████████▋| 411/422 [03:10<00:05,  2.13it/s]
#
#
#  98%|█████████▊| 412/422 [03:10<00:04,  2.16it/s]
#
#
#  98%|█████████▊| 413/422 [03:11<00:04,  2.17it/s]
#
#
#  98%|█████████▊| 414/422 [03:11<00:03,  2.19it/s]
#
#
#  98%|█████████▊| 415/422 [03:11<00:03,  2.20it/s]
#
#
#  99%|█████████▊| 416/422 [03:12<00:02,  2.22it/s]
#
#
#  99%|█████████▉| 417/422 [03:12<00:02,  2.22it/s]
#
#
#  99%|█████████▉| 418/422 [03:13<00:01,  2.23it/s]
#
#
#  99%|█████████▉| 419/422 [03:13<00:01,  2.23it/s]
#
#
# 100%|█████████▉| 420/422 [03:14<00:00,  2.23it/s]
#
#
# 100%|█████████▉| 421/422 [03:14<00:00,  2.22it/s]
#
#
# 100%|██████████| 422/422 [03:15<00:00,  2.16it/s]

# %%
sorted_topic_sims = sorted(topic_kw_sims.items(),
                          key=lambda kv: kv[1],
                          reverse=False)
print('Most similar topics:')
tmp_list = [(t,s) for (t,s) in sorted_topic_sims if s>0]
pprint(tmp_list[:50])
print("\nLeast similar topics:")
tmp_list = [(t,s) for (t,s) in sorted_topic_sims if not math.isinf(s)]
pprint(tmp_list[-50:])

print("\nTopics with sim > 1:")
#pprint([(t,s) for (t,s) in sorted_topic_sims if s>1])
print(len([(t,s) for (t,s) in sorted_topic_sims if s>1 and not math.isinf(s)]))
print("\nTopics with sim <= 1:")
print(len([(t,s) for (t,s) in sorted_topic_sims if s<=1 and s>0]))
print("\nTopics with sim ~ 1:")
tmp_list = [(t,s) for (t,s) in sorted_topic_sims if s<=1.1 and s>1]
print(len(tmp_list))
pprint(tmp_list[:50])
# Out:
# Most similar topics:
# [('rural_development_programmes-rural_development_programme',
#   0.23732740663783877),
#  ('flemish_region-walloon_region', 0.26490518466144797),
#  ('walloon_region-flemish_region', 0.26490518466144797),
#  ('natural_renewable_resources-renewable_natural_resource', 0.2743844392672613),
#  ('european_union_law-european_union_legislation', 0.28949777664433396),
#  ('extreme_weather_events-extreme_weather_event', 0.29311810665329063),
#  ('permanent_pastures-permanent_pasture', 0.297483636610508),
#  ('heat_waves-heat_wave', 0.30928613990670445),
#  ('water_resource_management-integrate_water_resource_management',
#   0.31116352029111627),
#  ('permanent_grassland-permanent_pasture', 0.32462382358700037),
#  ('agricultural_prices-agricultural_price', 0.3388956938678026),
#  ('agricultural_sector-agricultural_horticultural_sector', 0.34673294755021217),
#  ('food_supply_chain-food_supply', 0.35268685729629484),
#  ('global_climate_change-climate_change', 0.3527671807930535),
#  ('utilized_agricultural_area-utilise_agricultural_area', 0.3543767931659649),
#  ('water_resource_management-water_resource_development', 0.3572760481407985),
#  ('european_legislation-national_european_legislation', 0.36081373558418633),
#  ('direct_financial_support-direct_income_support', 0.36451145718000927),
#  ('arable_crops-arable_crop', 0.3648471838492155),
#  ('european_legislation-european_union_legislation', 0.3678233436607524),
#  ('water_resource_management-water_resource_exploitation', 0.3678388477789179),
#  ('water_resource_management-water_management_policy', 0.3712141588481454),
#  ('food_supply_chain-food_chain', 0.3721811753234458),
#  ('arable_land-irrigate_arable_land', 0.3730946355891412),
#  ('water_resource_management-water_resource_allocation', 0.37726903187332345),
#  ('agricultural_policies-agricultural_policy', 0.37824744011354444),
#  ('water_management-water_resource_management', 0.37995938713631067),
#  ('water_resource_management-water_management', 0.37995938713631067),
#  ('innovative_business_models-innovative_business', 0.3839123386650337),
#  ('organic_production-organic_animal_production', 0.3843107701671175),
#  ('rural_development_measures-rural_development_programme',
#   0.38485126864969815),
#  ('rural_development-rural_development_programme', 0.387208778195031),
#  ('water_resource_management-water_resource', 0.38798882901278897),
#  ('water_management-water_management_policy', 0.3904048822004294),
#  ('large_companies-large_company', 0.3911187225716114),
#  ('european_union_law-european_union_level', 0.3912902718932644),
#  ('utilized_agricultural_area-agricultural_area', 0.3921534066451021),
#  ('local_food_production-entire_food_production', 0.3928127663612037),
#  ('local_food_production-additional_food_production', 0.3940807322869194),
#  ('climate_change_effects-climate_change', 0.39458531642697914),
#  ('rural_policy-european_rural_policy', 0.3952593988192457),
#  ('rural_development_programmes-rural_development', 0.3957764818289975),
#  ('urban_areas-urban_area', 0.39628739638996124),
#  ('rural_areas-rural_area', 0.39628743169838193),
#  ('local_food_production-increase_food_production', 0.3990708661106736),
#  ('annual_production-annual_cereal_production', 0.4009994864588677),
#  ('agricultural_sector-agricultural_food_sector', 0.40151907357067024),
#  ('high_production_costs-high_production', 0.40200329670943435),
#  ('direct_financial_support-direct_support', 0.4030744291299006),
#  ('water_resource_management-water_management_decision', 0.4038415133351242)]
#
# Least similar topics:
# [('demographic_ageing-shah', 1.4164977904129028),
#  ('industrial_development-vmm', 1.4170649059546592),
#  ('smaller_enterprises-cline', 1.417287581870556),
#  ('new_jobs-vmm', 1.4177403932344317),
#  ('marine_environment-loser', 1.4182706098519564),
#  ('low_carbon-orchard', 1.4186012070441247),
#  ('territorial_planning-cline', 1.4188974001763464),
#  ('public_goods-cline', 1.4190837735027073),
#  ('low_productivity-vmm', 1.4192026346160174),
#  ('permanent_grassland-squirt', 1.4193276309311986),
#  ('direct_sale-vmm', 1.419764239215374),
#  ('direct_sale-relic', 1.4198268874406814),
#  ('limited_financing-els_demuynck', 1.421206424715042),
#  ('limited_financing-2009_els_bernaert', 1.421206424715042),
#  ('permanent_pastures-squirt', 1.4215934348554016),
#  ('credit_financing-reaper', 1.4216819467961788),
#  ('young_women-vmm', 1.422703749294877),
#  ('rural_diversification-vmm', 1.4231713471382856),
#  ('technical_innovations-vmm', 1.4233822888548373),
#  ('new_buildings-vmm', 1.4239747749160527),
#  ('adequate_funding-reaper', 1.4242228126273155),
#  ('settlement_structure-sint_katelijne_waver', 1.4243368607788087),
#  ('population_change-vmm', 1.4244243366247415),
#  ('innovative_tools-vmm', 1.425858022904396),
#  ('innovative_tools-sint_katelijne_waver', 1.4273005046750307),
#  ('land_abandonment-lmn', 1.4274295158423185),
#  ('new_solutions-vmm', 1.427665494351983),
#  ('age_structure-sint_katelijne_waver', 1.4278496251373292),
#  ('new_business_models-vmm', 1.4278793761735356),
#  ('capital_investment-reaper', 1.427970603896141),
#  ('technological_advancements-vmm', 1.4279926240773202),
#  ('small_enterprises-cline', 1.4289135045210122),
#  ('new_building-vmm', 1.4293756523447037),
#  ('technological_progress-vmm', 1.4304181985101103),
#  ('innovative_business_models-vmm', 1.4309158236144468),
#  ('innovative_solutions-fadn', 1.4313279294791819),
#  ('innovative_solutions-vmm', 1.432219454241991),
#  ('young_people-vmm', 1.433150000846386),
#  ('technological_developments-vmm', 1.4333220954955816),
#  ('agricultural_diversification-vmm', 1.4334673428382874),
#  ('circular_economy-gallinago_gallinago', 1.433764590382576),
#  ('public_good-cline', 1.4370869169753193),
#  ('technological_innovations-vmm', 1.4386581624796986),
#  ('technological_advances-vmm', 1.4390765743370058),
#  ('technological_changes-vmm', 1.439283069467783),
#  ('novel_approaches-vmm', 1.4412758846662044),
#  ('new_methods-vmm', 1.4425542236099242),
#  ('new_approaches-vmm', 1.4468588068020345),
#  ('innovative_approaches-vmm', 1.4514134874131084),
#  ('new_strategies-vmm', 1.4692528003590704)]
#
# Topics with sim > 1:
# 1150600
#
# Topics with sim <= 1:
# 7759
#
# Topics with sim ~ 1:
# 7062
# [('regional_inequalities-local_fluctuation', 1.0000182374854087),
#  ('innovative_business_models-model', 1.0001005118220396),
#  ('secondary_level-low_cost_catastrophic_cat_coverage_level',
#   1.0001318864685227),
#  ('agricultural_policies-european_rural_policy', 1.0002112377655545),
#  ('larger_companies-large_team', 1.0003542141866684),
#  ('digital_skills-skill', 1.000405104326248),
#  ('rural_regions-region_farm', 1.0004612056463957),
#  ('agricultural_landscape-horticultural_sector', 1.0004671198769808),
#  ('water_management-freshwater_resource', 1.0005165672367216),
#  ('high_transport_costs-management_cost', 1.0005590444960581),
#  ('regional_development-local_population', 1.000646719801426),
#  ('cultural_heritage-landscape', 1.000694820549786),
#  ('rural_policy-urban_demand', 1.000735634667754),
#  ('new_farmers-new_multi_risk_multi_crop_policy', 1.0007664345731198),
#  ('high_transport_costs-cost_reduction', 1.0009471229432583),
#  ('rural_industry-arable_sector', 1.000950396982789),
#  ('high_regulation-call_high_nature_value_farmland', 1.0009955540922284),
#  ('organic_agriculture-forestry', 1.001139177019596),
#  ('organic_farming-livestock', 1.001165170115471),
#  ('local_food-regional_guarantee', 1.0012073064541818),
#  ('foreign_workers-illegal_worker', 1.0012402866835595),
#  ('industrial_development-technological_advancement', 1.0013219518951773),
#  ('ecological_agriculture-greenhouse_horticulture', 1.0013436077432631),
#  ('low_productivity-high_input_cost', 1.001357592152703),
#  ('food_supply_chain-domestic_food_security_poverty_alleviation',
#   1.001408388540069),
#  ('land_planning-major_usually_dominant_land_use', 1.0014717709866763),
#  ('credit_financing-financial_institution', 1.0014932039368152),
#  ('arable_crops-permanent_pasture', 1.0015768452376126),
#  ('novel_approaches-unique_method', 1.0015919467191696),
#  ('arable_land-grassland_bird', 1.0016265340313912),
#  ('small_firms-large_segment', 1.001670577674806),
#  ('urban_areas-large_area', 1.0017532603096961),
#  ('high_transport_costs-total_premium_cost', 1.0017855145103474),
#  ('agricultural_employees-horticultural_sector', 1.0017940948534012),
#  ('large_companies-small_fruit', 1.0018080334846973),
#  ('rural_areas-total_area', 1.0019851374344229),
#  ('medical_services-service', 1.001985823377788),
#  ('small_companies-company_level', 1.0020464044767619),
#  ('arable_crops-heathland_grassland_habitat', 1.002055958935746),
#  ('small_firms-large_volume', 1.0022391234750152),
#  ('larger_companies-large_employer', 1.0023035123425723),
#  ('soil_erosion-deforestation', 1.0023743373473881),
#  ('demographic_developments-economic_development', 1.0024469019201994),
#  ('cap_policies-change_policy', 1.002455675497055),
#  ('rural_areas-crop_area', 1.0025170727143289),
#  ('low_productivity-high_risk_crop', 1.0025834415332808),
#  ('high_transport_costs-subsidized_low_charge', 1.0029593549191218),
#  ('land_consolidation-major_usually_dominant_land_use', 1.002963423104763),
#  ('smaller_enterprises-small_company_size', 1.003022177136264),
#  ('rural_infrastructure-urban_demand', 1.0030351315827368)]

# %%
topic_kw_sims_raw = {}  
for i in tqdm(range(len(topics))):
    for j in range(len(keywords_raw)):
        topic1 = topics[i]
        topic2 = keywords_raw[j]
        wmd = model.wmdistance(topic1.split("_"), topic2.split(" ")) 
        t_key = "{}-{}".format(topic1, topic2)
        topic_kw_sims_raw[t_key] = wmd
# Out:
#   0%|          | 0/422 [00:00<?, ?it/s]
#
#
#   0%|          | 1/422 [00:00<03:37,  1.94it/s]
#
#
#   0%|          | 2/422 [00:01<03:37,  1.93it/s]
#
#
#   1%|          | 3/422 [00:01<03:36,  1.94it/s]
#
#
#   1%|          | 4/422 [00:02<03:37,  1.92it/s]
#
#
#   1%|          | 5/422 [00:02<03:36,  1.93it/s]
#
#
#   1%|▏         | 6/422 [00:03<03:35,  1.93it/s]
#
#
#   2%|▏         | 7/422 [00:03<03:34,  1.93it/s]
#
#
#   2%|▏         | 8/422 [00:04<03:33,  1.94it/s]
#
#
#   2%|▏         | 9/422 [00:04<03:34,  1.93it/s]
#
#
#   2%|▏         | 10/422 [00:05<03:34,  1.92it/s]
#
#
#   3%|▎         | 11/422 [00:05<03:34,  1.91it/s]
#
#
#   3%|▎         | 12/422 [00:06<03:49,  1.79it/s]
#
#
#   3%|▎         | 13/422 [00:06<03:44,  1.82it/s]
#
#
#   3%|▎         | 14/422 [00:07<03:39,  1.85it/s]
#
#
#   4%|▎         | 15/422 [00:07<03:36,  1.88it/s]
#
#
#   4%|▍         | 16/422 [00:08<03:50,  1.76it/s]
#
#
#   4%|▍         | 17/422 [00:09<03:45,  1.80it/s]
#
#
#   4%|▍         | 18/422 [00:09<03:42,  1.82it/s]
#
#
#   5%|▍         | 19/422 [00:10<03:38,  1.84it/s]
#
#
#   5%|▍         | 20/422 [00:10<03:36,  1.86it/s]
#
#
#   5%|▍         | 21/422 [00:11<03:32,  1.89it/s]
#
#
#   5%|▌         | 22/422 [00:11<03:28,  1.92it/s]
#
#
#   5%|▌         | 23/422 [00:12<03:29,  1.90it/s]
#
#
#   6%|▌         | 24/422 [00:12<03:28,  1.91it/s]
#
#
#   6%|▌         | 25/422 [00:13<03:26,  1.93it/s]
#
#
#   6%|▌         | 26/422 [00:13<03:38,  1.82it/s]
#
#
#   6%|▋         | 27/422 [00:14<03:32,  1.86it/s]
#
#
#   7%|▋         | 28/422 [00:14<03:28,  1.89it/s]
#
#
#   7%|▋         | 29/422 [00:15<03:40,  1.78it/s]
#
#
#   7%|▋         | 30/422 [00:16<03:34,  1.83it/s]
#
#
#   7%|▋         | 31/422 [00:16<03:29,  1.86it/s]
#
#
#   8%|▊         | 32/422 [00:17<03:25,  1.90it/s]
#
#
#   8%|▊         | 33/422 [00:17<03:21,  1.93it/s]
#
#
#   8%|▊         | 34/422 [00:18<03:19,  1.95it/s]
#
#
#   8%|▊         | 35/422 [00:18<03:17,  1.96it/s]
#
#
#   9%|▊         | 36/422 [00:19<03:17,  1.96it/s]
#
#
#   9%|▉         | 37/422 [00:19<03:14,  1.98it/s]
#
#
#   9%|▉         | 38/422 [00:20<03:14,  1.97it/s]
#
#
#   9%|▉         | 39/422 [00:20<03:15,  1.96it/s]
#
#
#   9%|▉         | 40/422 [00:21<03:15,  1.95it/s]
#
#
#  10%|▉         | 41/422 [00:21<03:15,  1.95it/s]
#
#
#  10%|▉         | 42/422 [00:22<03:14,  1.96it/s]
#
#
#  10%|█         | 43/422 [00:22<03:16,  1.93it/s]
#
#
#  10%|█         | 44/422 [00:23<03:17,  1.92it/s]
#
#
#  11%|█         | 45/422 [00:23<03:15,  1.92it/s]
#
#
#  11%|█         | 46/422 [00:24<03:14,  1.93it/s]
#
#
#  11%|█         | 47/422 [00:24<03:13,  1.94it/s]
#
#
#  11%|█▏        | 48/422 [00:25<03:27,  1.80it/s]
#
#
#  12%|█▏        | 49/422 [00:25<03:23,  1.83it/s]
#
#
#  12%|█▏        | 50/422 [00:26<03:34,  1.73it/s]
#
#
#  12%|█▏        | 51/422 [00:27<03:25,  1.81it/s]
#
#
#  12%|█▏        | 52/422 [00:27<03:19,  1.85it/s]
#
#
#  13%|█▎        | 53/422 [00:28<03:15,  1.88it/s]
#
#
#  13%|█▎        | 54/422 [00:28<03:12,  1.91it/s]
#
#
#  13%|█▎        | 55/422 [00:29<03:10,  1.93it/s]
#
#
#  13%|█▎        | 56/422 [00:29<03:07,  1.95it/s]
#
#
#  14%|█▎        | 57/422 [00:30<03:07,  1.94it/s]
#
#
#  14%|█▎        | 58/422 [00:30<03:06,  1.95it/s]
#
#
#  14%|█▍        | 59/422 [00:31<03:04,  1.97it/s]
#
#
#  14%|█▍        | 60/422 [00:31<03:18,  1.82it/s]
#
#
#  14%|█▍        | 61/422 [00:32<03:13,  1.86it/s]
#
#
#  15%|█▍        | 62/422 [00:32<03:09,  1.90it/s]
#
#
#  15%|█▍        | 63/422 [00:33<03:07,  1.92it/s]
#
#
#  15%|█▌        | 64/422 [00:33<03:04,  1.94it/s]
#
#
#  15%|█▌        | 65/422 [00:34<03:02,  1.96it/s]
#
#
#  16%|█▌        | 66/422 [00:34<03:02,  1.95it/s]
#
#
#  16%|█▌        | 67/422 [00:35<03:01,  1.96it/s]
#
#
#  16%|█▌        | 68/422 [00:35<03:00,  1.97it/s]
#
#
#  16%|█▋        | 69/422 [00:36<02:59,  1.96it/s]
#
#
#  17%|█▋        | 70/422 [00:36<02:59,  1.97it/s]
#
#
#  17%|█▋        | 71/422 [00:37<03:12,  1.82it/s]
#
#
#  17%|█▋        | 72/422 [00:37<03:08,  1.86it/s]
#
#
#  17%|█▋        | 73/422 [00:38<03:19,  1.75it/s]
#
#
#  18%|█▊        | 74/422 [00:39<03:13,  1.79it/s]
#
#
#  18%|█▊        | 75/422 [00:39<03:07,  1.85it/s]
#
#
#  18%|█▊        | 76/422 [00:40<03:02,  1.89it/s]
#
#
#  18%|█▊        | 77/422 [00:40<02:59,  1.92it/s]
#
#
#  18%|█▊        | 78/422 [00:41<03:09,  1.81it/s]
#
#
#  19%|█▊        | 79/422 [00:41<03:04,  1.86it/s]
#
#
#  19%|█▉        | 80/422 [00:42<02:59,  1.90it/s]
#
#
#  19%|█▉        | 81/422 [00:42<02:57,  1.92it/s]
#
#
#  19%|█▉        | 82/422 [00:43<02:54,  1.95it/s]
#
#
#  20%|█▉        | 83/422 [00:43<02:52,  1.97it/s]
#
#
#  20%|█▉        | 84/422 [00:44<02:50,  1.98it/s]
#
#
#  20%|██        | 85/422 [00:44<02:48,  1.99it/s]
#
#
#  20%|██        | 86/422 [00:45<02:48,  1.99it/s]
#
#
#  21%|██        | 87/422 [00:45<02:47,  2.00it/s]
#
#
#  21%|██        | 88/422 [00:46<02:46,  2.00it/s]
#
#
#  21%|██        | 89/422 [00:46<02:48,  1.98it/s]
#
#
#  21%|██▏       | 90/422 [00:47<02:47,  1.98it/s]
#
#
#  22%|██▏       | 91/422 [00:47<02:46,  1.98it/s]
#
#
#  22%|██▏       | 92/422 [00:48<02:45,  1.99it/s]
#
#
#  22%|██▏       | 93/422 [00:48<02:44,  2.00it/s]
#
#
#  22%|██▏       | 94/422 [00:49<02:43,  2.00it/s]
#
#
#  23%|██▎       | 95/422 [00:49<02:43,  2.01it/s]
#
#
#  23%|██▎       | 96/422 [00:50<02:42,  2.00it/s]
#
#
#  23%|██▎       | 97/422 [00:50<02:43,  1.99it/s]
#
#
#  23%|██▎       | 98/422 [00:51<02:42,  2.00it/s]
#
#
#  23%|██▎       | 99/422 [00:51<02:41,  1.99it/s]
#
#
#  24%|██▎       | 100/422 [00:52<02:42,  1.99it/s]
#
#
#  24%|██▍       | 101/422 [00:52<02:42,  1.98it/s]
#
#
#  24%|██▍       | 102/422 [00:53<02:54,  1.84it/s]
#
#
#  24%|██▍       | 103/422 [00:53<02:48,  1.89it/s]
#
#
#  25%|██▍       | 104/422 [00:54<02:45,  1.93it/s]
#
#
#  25%|██▍       | 105/422 [00:54<02:43,  1.94it/s]
#
#
#  25%|██▌       | 106/422 [00:55<02:42,  1.94it/s]
#
#
#  25%|██▌       | 107/422 [00:55<02:42,  1.93it/s]
#
#
#  26%|██▌       | 108/422 [00:56<02:43,  1.92it/s]
#
#
#  26%|██▌       | 109/422 [00:57<02:40,  1.94it/s]
#
#
#  26%|██▌       | 110/422 [00:57<02:39,  1.96it/s]
#
#
#  26%|██▋       | 111/422 [00:58<02:52,  1.81it/s]
#
#
#  27%|██▋       | 112/422 [00:58<02:47,  1.86it/s]
#
#
#  27%|██▋       | 113/422 [00:59<02:43,  1.89it/s]
#
#
#  27%|██▋       | 114/422 [00:59<02:43,  1.88it/s]
#
#
#  27%|██▋       | 115/422 [01:00<02:40,  1.91it/s]
#
#
#  27%|██▋       | 116/422 [01:00<02:42,  1.88it/s]
#
#
#  28%|██▊       | 117/422 [01:01<02:48,  1.81it/s]
#
#
#  28%|██▊       | 118/422 [01:01<02:44,  1.85it/s]
#
#
#  28%|██▊       | 119/422 [01:02<02:42,  1.87it/s]
#
#
#  28%|██▊       | 120/422 [01:02<02:38,  1.90it/s]
#
#
#  29%|██▊       | 121/422 [01:03<02:36,  1.92it/s]
#
#
#  29%|██▉       | 122/422 [01:03<02:33,  1.95it/s]
#
#
#  29%|██▉       | 123/422 [01:04<02:32,  1.96it/s]
#
#
#  29%|██▉       | 124/422 [01:04<02:31,  1.97it/s]
#
#
#  30%|██▉       | 125/422 [01:05<02:30,  1.98it/s]
#
#
#  30%|██▉       | 126/422 [01:05<02:28,  1.99it/s]
#
#
#  30%|███       | 127/422 [01:06<02:29,  1.98it/s]
#
#
#  30%|███       | 128/422 [01:06<02:28,  1.98it/s]
#
#
#  31%|███       | 129/422 [01:07<02:28,  1.98it/s]
#
#
#  31%|███       | 130/422 [01:08<02:39,  1.83it/s]
#
#
#  31%|███       | 131/422 [01:08<02:35,  1.87it/s]
#
#
#  31%|███▏      | 132/422 [01:09<02:32,  1.90it/s]
#
#
#  32%|███▏      | 133/422 [01:09<02:31,  1.91it/s]
#
#
#  32%|███▏      | 134/422 [01:10<02:29,  1.92it/s]
#
#
#  32%|███▏      | 135/422 [01:10<02:28,  1.94it/s]
#
#
#  32%|███▏      | 136/422 [01:11<02:26,  1.95it/s]
#
#
#  32%|███▏      | 137/422 [01:11<02:25,  1.96it/s]
#
#
#  33%|███▎      | 138/422 [01:12<02:25,  1.96it/s]
#
#
#  33%|███▎      | 139/422 [01:12<02:37,  1.80it/s]
#
#
#  33%|███▎      | 140/422 [01:13<02:44,  1.72it/s]
#
#
#  33%|███▎      | 141/422 [01:13<02:37,  1.78it/s]
#
#
#  34%|███▎      | 142/422 [01:14<02:31,  1.85it/s]
#
#
#  34%|███▍      | 143/422 [01:14<02:27,  1.90it/s]
#
#
#  34%|███▍      | 144/422 [01:15<02:23,  1.93it/s]
#
#
#  34%|███▍      | 145/422 [01:15<02:21,  1.95it/s]
#
#
#  35%|███▍      | 146/422 [01:16<02:19,  1.97it/s]
#
#
#  35%|███▍      | 147/422 [01:17<02:29,  1.85it/s]
#
#
#  35%|███▌      | 148/422 [01:17<02:24,  1.90it/s]
#
#
#  35%|███▌      | 149/422 [01:18<02:21,  1.93it/s]
#
#
#  36%|███▌      | 150/422 [01:18<02:18,  1.96it/s]
#
#
#  36%|███▌      | 151/422 [01:19<02:17,  1.98it/s]
#
#
#  36%|███▌      | 152/422 [01:19<02:15,  1.99it/s]
#
#
#  36%|███▋      | 153/422 [01:20<02:24,  1.86it/s]
#
#
#  36%|███▋      | 154/422 [01:20<02:20,  1.90it/s]
#
#
#  37%|███▋      | 155/422 [01:21<02:17,  1.94it/s]
#
#
#  37%|███▋      | 156/422 [01:21<02:14,  1.97it/s]
#
#
#  37%|███▋      | 157/422 [01:22<02:13,  1.99it/s]
#
#
#  37%|███▋      | 158/422 [01:22<02:12,  2.00it/s]
#
#
#  38%|███▊      | 159/422 [01:23<02:10,  2.01it/s]
#
#
#  38%|███▊      | 160/422 [01:23<02:10,  2.01it/s]
#
#
#  38%|███▊      | 161/422 [01:24<02:09,  2.02it/s]
#
#
#  38%|███▊      | 162/422 [01:24<02:08,  2.02it/s]
#
#
#  39%|███▊      | 163/422 [01:25<02:08,  2.02it/s]
#
#
#  39%|███▉      | 164/422 [01:25<02:07,  2.02it/s]
#
#
#  39%|███▉      | 165/422 [01:26<02:06,  2.02it/s]
#
#
#  39%|███▉      | 166/422 [01:26<02:06,  2.03it/s]
#
#
#  40%|███▉      | 167/422 [01:27<02:05,  2.02it/s]
#
#
#  40%|███▉      | 168/422 [01:27<02:05,  2.02it/s]
#
#
#  40%|████      | 169/422 [01:28<02:24,  1.75it/s]
#
#
#  40%|████      | 170/422 [01:28<02:17,  1.83it/s]
#
#
#  41%|████      | 171/422 [01:29<02:13,  1.88it/s]
#
#
#  41%|████      | 172/422 [01:29<02:10,  1.92it/s]
#
#
#  41%|████      | 173/422 [01:30<02:07,  1.95it/s]
#
#
#  41%|████      | 174/422 [01:30<02:05,  1.98it/s]
#
#
#  41%|████▏     | 175/422 [01:31<02:04,  1.99it/s]
#
#
#  42%|████▏     | 176/422 [01:31<02:02,  2.00it/s]
#
#
#  42%|████▏     | 177/422 [01:32<02:01,  2.01it/s]
#
#
#  42%|████▏     | 178/422 [01:32<02:01,  2.01it/s]
#
#
#  42%|████▏     | 179/422 [01:33<02:01,  2.01it/s]
#  52%|█████▏    | 221/422 [01:54<01:40,  2.01it/s]
#
#
#  53%|█████▎    | 222/422 [01:54<01:41,  1.98it/s]
#
#
#  53%|█████▎    | 223/422 [01:55<01:40,  1.98it/s]
#
#
#  53%|█████▎    | 224/422 [01:55<01:39,  1.98it/s]
#
#
#  53%|█████▎    | 225/422 [01:56<01:39,  1.98it/s]
#
#
#  54%|█████▎    | 226/422 [01:56<01:38,  1.99it/s]
#
#
#  54%|█████▍    | 227/422 [01:57<01:38,  1.99it/s]
#
#
#  54%|█████▍    | 228/422 [01:57<01:37,  1.99it/s]
#
#
#  54%|█████▍    | 229/422 [01:58<01:36,  1.99it/s]
#
#
#  55%|█████▍    | 230/422 [01:58<01:36,  1.99it/s]
#
#
#  55%|█████▍    | 231/422 [01:59<01:35,  1.99it/s]
#
#
#  55%|█████▍    | 232/422 [01:59<01:35,  1.99it/s]
#
#
#  55%|█████▌    | 233/422 [02:00<01:34,  2.00it/s]
#
#
#  55%|█████▌    | 234/422 [02:00<01:34,  2.00it/s]
#
#
#  56%|█████▌    | 235/422 [02:01<01:34,  1.99it/s]
#
#
#  56%|█████▌    | 236/422 [02:01<01:33,  1.99it/s]
#
#
#  56%|█████▌    | 237/422 [02:02<01:33,  1.98it/s]
#
#
#  56%|█████▋    | 238/422 [02:03<01:33,  1.97it/s]
#
#
#  57%|█████▋    | 239/422 [02:03<01:32,  1.97it/s]
#
#
#  57%|█████▋    | 240/422 [02:04<01:32,  1.98it/s]
#
#
#  57%|█████▋    | 241/422 [02:04<01:31,  1.97it/s]
#
#
#  57%|█████▋    | 242/422 [02:05<01:31,  1.97it/s]
#
#
#  58%|█████▊    | 243/422 [02:05<01:30,  1.97it/s]
#
#
#  58%|█████▊    | 244/422 [02:06<01:30,  1.97it/s]
#
#
#  58%|█████▊    | 245/422 [02:06<01:29,  1.97it/s]
#
#
#  58%|█████▊    | 246/422 [02:07<01:28,  1.98it/s]
#
#
#  59%|█████▊    | 247/422 [02:07<01:28,  1.99it/s]
#
#
#  59%|█████▉    | 248/422 [02:08<01:27,  1.99it/s]
#
#
#  59%|█████▉    | 249/422 [02:08<01:26,  1.99it/s]
#
#
#  59%|█████▉    | 250/422 [02:09<01:26,  1.99it/s]
#
#
#  59%|█████▉    | 251/422 [02:09<01:26,  1.99it/s]
#
#
#  60%|█████▉    | 252/422 [02:10<01:25,  1.98it/s]
#
#
#  60%|█████▉    | 253/422 [02:10<01:25,  1.98it/s]
#
#
#  60%|██████    | 254/422 [02:11<01:24,  1.98it/s]
#
#
#  60%|██████    | 255/422 [02:11<01:24,  1.99it/s]
#
#
#  61%|██████    | 256/422 [02:12<01:30,  1.84it/s]
#
#
#  61%|██████    | 257/422 [02:12<01:27,  1.88it/s]
#
#
#  61%|██████    | 258/422 [02:13<01:25,  1.91it/s]
#
#
#  61%|██████▏   | 259/422 [02:13<01:24,  1.93it/s]
#
#
#  62%|██████▏   | 260/422 [02:14<01:29,  1.80it/s]
#
#
#  62%|██████▏   | 261/422 [02:14<01:26,  1.85it/s]
#  81%|████████▏ | 343/422 [02:58<00:40,  1.96it/s]
#
#
#  82%|████████▏ | 344/422 [02:59<00:39,  1.97it/s]
#
#
#  82%|████████▏ | 345/422 [02:59<00:39,  1.97it/s]
#
#
#  82%|████████▏ | 346/422 [03:00<00:38,  1.98it/s]
#
#
#  82%|████████▏ | 347/422 [03:00<00:37,  1.98it/s]
#
#
#  82%|████████▏ | 348/422 [03:01<00:37,  1.98it/s]
#
#
#  83%|████████▎ | 349/422 [03:01<00:36,  1.98it/s]
#
#
#  83%|████████▎ | 350/422 [03:02<00:36,  1.98it/s]
#
#
#  83%|████████▎ | 351/422 [03:02<00:35,  1.99it/s]
#
#
#  83%|████████▎ | 352/422 [03:03<00:35,  1.99it/s]
#
#
#  84%|████████▎ | 353/422 [03:03<00:34,  1.99it/s]
#
#
#  84%|████████▍ | 354/422 [03:04<00:34,  1.99it/s]
#
#
#  84%|████████▍ | 355/422 [03:04<00:33,  1.99it/s]
#
#
#  84%|████████▍ | 356/422 [03:05<00:33,  1.99it/s]
#
#
#  85%|████████▍ | 357/422 [03:05<00:32,  1.98it/s]
#
#
#  85%|████████▍ | 358/422 [03:06<00:32,  1.97it/s]
#
#
#  85%|████████▌ | 359/422 [03:06<00:32,  1.96it/s]
#
#
#  85%|████████▌ | 360/422 [03:07<00:34,  1.82it/s]
#
#
#  86%|████████▌ | 361/422 [03:08<00:32,  1.87it/s]
#
#
#  86%|████████▌ | 362/422 [03:08<00:31,  1.90it/s]
#
#
#  86%|████████▌ | 363/422 [03:09<00:30,  1.92it/s]
#
#
#  86%|████████▋ | 364/422 [03:09<00:29,  1.94it/s]
#
#
#  86%|████████▋ | 365/422 [03:10<00:29,  1.95it/s]
#
#
#  87%|████████▋ | 366/422 [03:10<00:28,  1.96it/s]
#
#
#  87%|████████▋ | 367/422 [03:11<00:28,  1.96it/s]
#
#
#  87%|████████▋ | 368/422 [03:11<00:27,  1.97it/s]
#
#
#  87%|████████▋ | 369/422 [03:12<00:26,  1.97it/s]
#
#
#  88%|████████▊ | 370/422 [03:12<00:26,  1.98it/s]
#
#
#  88%|████████▊ | 371/422 [03:13<00:29,  1.71it/s]
#
#
#  88%|████████▊ | 372/422 [03:13<00:28,  1.79it/s]
#
#
#  88%|████████▊ | 373/422 [03:14<00:26,  1.84it/s]
#
#
#  89%|████████▊ | 374/422 [03:14<00:25,  1.88it/s]
#
#
#  89%|████████▉ | 375/422 [03:15<00:24,  1.91it/s]
#
#
#  89%|████████▉ | 376/422 [03:15<00:23,  1.93it/s]
#
#
#  89%|████████▉ | 377/422 [03:16<00:23,  1.94it/s]
#
#
#  90%|████████▉ | 378/422 [03:16<00:22,  1.95it/s]
#
#
#  90%|████████▉ | 379/422 [03:17<00:21,  1.96it/s]
#
#
#  90%|█████████ | 380/422 [03:17<00:21,  1.97it/s]
#
#
#  90%|█████████ | 381/422 [03:18<00:20,  1.97it/s]
#
#
#  91%|█████████ | 382/422 [03:18<00:20,  1.98it/s]
#
#
#  91%|█████████ | 383/422 [03:19<00:19,  1.98it/s]
#
#
#  91%|█████████ | 384/422 [03:19<00:19,  1.98it/s]
#
#
#  91%|█████████ | 385/422 [03:20<00:18,  1.98it/s]
#
#
#  91%|█████████▏| 386/422 [03:20<00:18,  1.98it/s]
#
#
#  92%|█████████▏| 387/422 [03:21<00:17,  1.97it/s]
#
#
#  92%|█████████▏| 388/422 [03:21<00:17,  1.98it/s]
#
#
#  92%|█████████▏| 389/422 [03:22<00:16,  1.98it/s]
#
#
#  92%|█████████▏| 390/422 [03:22<00:16,  1.98it/s]
#
#
#  93%|█████████▎| 391/422 [03:23<00:15,  1.99it/s]
#
#
#  93%|█████████▎| 392/422 [03:23<00:15,  1.98it/s]
#
#
#  93%|█████████▎| 393/422 [03:24<00:14,  1.98it/s]
#
#
#  93%|█████████▎| 394/422 [03:24<00:14,  1.98it/s]
#
#
#  94%|█████████▎| 395/422 [03:25<00:13,  1.98it/s]
#
#
#  94%|█████████▍| 396/422 [03:25<00:13,  1.98it/s]
#
#
#  94%|█████████▍| 397/422 [03:26<00:12,  1.98it/s]
#
#
#  94%|█████████▍| 398/422 [03:27<00:12,  1.98it/s]
#
#
#  95%|█████████▍| 399/422 [03:27<00:12,  1.85it/s]
#
#
#  95%|█████████▍| 400/422 [03:28<00:11,  1.90it/s]
#
#
#  95%|█████████▌| 401/422 [03:28<00:10,  1.93it/s]
#
#
#  95%|█████████▌| 402/422 [03:29<00:10,  1.94it/s]
#
#
#  95%|█████████▌| 403/422 [03:29<00:09,  1.96it/s]
#
#
#  96%|█████████▌| 404/422 [03:30<00:09,  1.83it/s]
#
#
#  96%|█████████▌| 405/422 [03:30<00:09,  1.86it/s]
#
#
#  96%|█████████▌| 406/422 [03:31<00:08,  1.90it/s]
#
#
#  96%|█████████▋| 407/422 [03:31<00:08,  1.79it/s]
#
#
#  97%|█████████▋| 408/422 [03:32<00:08,  1.72it/s]
#
#
#  97%|█████████▋| 409/422 [03:33<00:07,  1.80it/s]
#
#
#  97%|█████████▋| 410/422 [03:33<00:06,  1.85it/s]
#
#
#  97%|█████████▋| 411/422 [03:34<00:05,  1.89it/s]
#
#
#  98%|█████████▊| 412/422 [03:34<00:05,  1.92it/s]
#
#
#  98%|█████████▊| 413/422 [03:35<00:04,  1.94it/s]
#
#
#  98%|█████████▊| 414/422 [03:35<00:04,  1.96it/s]
#
#
#  98%|█████████▊| 415/422 [03:36<00:03,  1.97it/s]
#
#
#  99%|█████████▊| 416/422 [03:36<00:03,  1.99it/s]
#
#
#  99%|█████████▉| 417/422 [03:37<00:02,  2.00it/s]
#
#
#  99%|█████████▉| 418/422 [03:37<00:01,  2.00it/s]
#
#
#  99%|█████████▉| 419/422 [03:38<00:01,  2.01it/s]
#
#
# 100%|█████████▉| 420/422 [03:38<00:00,  2.01it/s]
#
#
# 100%|█████████▉| 421/422 [03:39<00:00,  2.01it/s]
#
#
# 100%|██████████| 422/422 [03:39<00:00,  1.92it/s]

# %%
sorted_topic_sims = sorted(topic_kw_sims_raw.items(),
                          key=lambda kv: kv[1],
                          reverse=False)

tmp_list = [(t,s) for (t,s) in sorted_topic_sims if s>0 and not math.isinf(s)]
print('Most similar topics:')
#tmp_list = [(t,s) for (t,s) in sorted_topic_sims if s>0]
pprint(tmp_list[:50])
print("\nLeast similar topics:")
#tmp_list = [(t,s) for (t,s) in sorted_topic_sims if not math.isinf(s)]
pprint(tmp_list[-50:])

print("\nTopics with sim > 1:")
#pprint([(t,s) for (t,s) in sorted_topic_sims if s>1])
print(len([(t,s) for (t,s) in sorted_topic_sims if s>1 and not math.isinf(s)]))
print("\nTopics with sim <= 1:")
print(len([(t,s) for (t,s) in sorted_topic_sims if s<=1 and s>0]))
# Out:
# Most similar topics:
# [('utilized_agricultural_area-utilised agricultural area', 0.2084471148268918),
#  ('smaller_businesses-larger businesses', 0.2745245962847471),
#  ('smaller_companies-larger companies', 0.27452466300517325),
#  ('fruit_and_vegetable_processing-vegetable and fruit cultivation',
#   0.28267063349574806),
#  ('permanent_pastures-permanent pasture', 0.297483636610508),
#  ('arable_land-irrigated arable land', 0.3089976498496879),
#  ('larger_firms-larger companies', 0.31842881084889174),
#  ('natural_renewable_resources-some renewable natural resources',
#   0.3216540398970706),
#  ('brussels_capital_region-the brussels capital region', 0.32418962150214653),
#  ('permanent_grassland-permanent pasture', 0.32462382358700037),
#  ('food_price-food prices', 0.3388962489104271),
#  ('global_climate_change-climate change', 0.3527671807930535),
#  ('climate_change-climate changes', 0.3566698082072735),
#  ('food_chain-food chains', 0.36261898729968073),
#  ('direct_financial_support-direct income support', 0.36451145718000927),
#  ('smaller_enterprises-smaller businesses', 0.3672644099850655),
#  ('larger_enterprises-larger businesses', 0.36726449168998004),
#  ('water_resource_management-water management policy', 0.3712141588481454),
#  ('larger_enterprises-larger companies', 0.37538158770221475),
#  ('agricultural_policies-agricultural policy', 0.37824744011354444),
#  ('water_management-water resource management', 0.37995938713631067),
#  ('water_resource_management-water management', 0.37995938713631067),
#  ('water_resources-surface water resources', 0.3828040321739729),
#  ('organic_production-organic animal production', 0.3843107701671175),
#  ('larger_companies-larger businesses', 0.38784109541666506),
#  ('smaller_companies-smaller businesses', 0.3878411982192993),
#  ('water_resources-water resources allocation', 0.3902600573284453),
#  ('water_management-water management policy', 0.3904048822004294),
#  ('european_union_law-european union level', 0.3912902718932644),
#  ('water_resources-water resources exploitation', 0.3913464575084273),
#  ('critical_raw_materials-raw materials', 0.39183809285278104),
#  ('utilized_agricultural_area-agricultural area', 0.3921534066451021),
#  ('natural_renewable_resources-natural resources', 0.3923056161510503),
#  ('water_scarcity-growing water scarcity', 0.39449371654098336),
#  ('climate_change_effects-climate change', 0.39458531642697914),
#  ('rural_development_programmes-rural development', 0.3957764818289975),
#  ('local_food_production-increased food production', 0.3960087684382624),
#  ('larger_firms-larger businesses', 0.3976051051002741),
#  ('smaller_firms-smaller businesses', 0.39760540224552154),
#  ('economic_development-the economic development', 0.39766298454906146),
#  ('annual_production-annual cereal production', 0.4009994864588677),
#  ('rural_development_measures-rural development increases', 0.4019051886381564),
#  ('high_production_costs-high production', 0.40200329670943435),
#  ('technological_progress-the technological progress', 0.4026786794755683),
#  ('direct_financial_support-direct support', 0.4030744291299006),
#  ('surface_water_bodies-surface water', 0.4054200145992624),
#  ('food_security-national food security', 0.4054314482200456),
#  ('water_scarcity-increased water scarcity', 0.4058768571181763),
#  ('surface_water_bodies-surface water resources', 0.4058892943422095),
#  ('rural_development_measures-rural development', 0.40609158499507175)]
#
# Least similar topics:
# [('asylum_seekers-combination', 1.4146984906390905),
#  ('small_enterprises-salinization', 1.41525843789649),
#  ('small_businesses-cline', 1.4158700910730362),
#  ('new_employment_opportunities-vmm', 1.415902007791028),
#  ('food_production-vmm', 1.4162180085328817),
#  ('innovative_approaches-fadn', 1.4162460417781473),
#  ('demographic_ageing-shah', 1.4164977904129028),
#  ('industrial_development-vmm', 1.4170649059546592),
#  ('smaller_enterprises-cline', 1.417287581870556),
#  ('new_jobs-vmm', 1.4177403932344317),
#  ('low_carbon-orchard', 1.4186012070441247),
#  ('territorial_planning-cline', 1.4188974001763464),
#  ('public_goods-cline', 1.4190837735027073),
#  ('low_productivity-vmm', 1.4192026346160174),
#  ('direct_sale-vmm', 1.419764239215374),
#  ('limited_financing-els demuynck', 1.421206424715042),
#  ('credit_financing-(historical)\n\na reaper', 1.4216819467961788),
#  ('young_women-vmm', 1.422703749294877),
#  ('rural_diversification-vmm', 1.4231713471382856),
#  ('technical_innovations-vmm', 1.4233822888548373),
#  ('educational_attainment-drips', 1.4238164418696166),
#  ('new_buildings-vmm', 1.4239747749160527),
#  ('adequate_funding-(historical)\n\na reaper', 1.4242228126273155),
#  ('population_change-vmm', 1.4244243366247415),
#  ('innovative_tools-vmm', 1.425858022904396),
#  ('land_abandonment-lmn', 1.4274295158423185),
#  ('cultural_heritage-drips', 1.427542346961975),
#  ('new_solutions-vmm', 1.427665494351983),
#  ('new_business_models-vmm', 1.4278793761735356),
#  ('capital_investment-(historical)\n\na reaper', 1.427970603896141),
#  ('technological_advancements-vmm', 1.4279926240773202),
#  ('small_enterprises-cline', 1.4289135045210122),
#  ('new_building-vmm', 1.4293756523447037),
#  ('technological_progress-vmm', 1.4304181985101103),
#  ('innovative_business_models-vmm', 1.4309158236144468),
#  ('innovative_solutions-fadn', 1.4313279294791819),
#  ('innovative_solutions-vmm', 1.432219454241991),
#  ('young_people-vmm', 1.433150000846386),
#  ('technological_developments-vmm', 1.4333220954955816),
#  ('agricultural_diversification-vmm', 1.4334673428382874),
#  ('circular_economy-gallinago gallinago', 1.433764590382576),
#  ('public_good-cline', 1.4370869169753193),
#  ('technological_innovations-vmm', 1.4386581624796986),
#  ('technological_advances-vmm', 1.4390765743370058),
#  ('technological_changes-vmm', 1.439283069467783),
#  ('novel_approaches-vmm', 1.4412758846662044),
#  ('new_methods-vmm', 1.4425542236099242),
#  ('new_approaches-vmm', 1.4468588068020345),
#  ('innovative_approaches-vmm', 1.4514134874131084),
#  ('new_strategies-vmm', 1.4692528003590704)]
#
# Topics with sim > 1:
# 1290037
#
# Topics with sim <= 1:
# 8005
